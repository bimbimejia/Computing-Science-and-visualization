# %% [markdown]
# # Tarea Dia 2

# %% [markdown]
# # Realizado en salome
#
# Para esta tarea cambie la parte interior del circulo que anteriormente era un circulo más pequeño a un cuadrado para ver como cambiaba el flujo. El proceso para crear el mesh fue el mismo con la excepción que en el momento de seleccionar los lados para crear la superficie se debian elegir los cuatro lados del cuadrado.

# %% [markdown]
# ![salome.PNG](attachment:salome.PNG)

# %% [markdown]
# # Realizado en Paraview

# %% [markdown]
# ![Paraview.PNG](attachment:Paraview.PNG)

# %% [markdown]
# En paraview se sigue el mismo proceso que en el trabajo realizado en clase haciendo uso de la calculadora.
