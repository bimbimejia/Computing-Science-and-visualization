# %% [markdown]
# # Tarea Dia 2

# %% [markdown]
# # realizado en salome

# %% [markdown]
# ![salome.PNG](attachment:salome.PNG)

# %% [markdown]
# # Realizado en Paraview

# %% [markdown]
# ![Paraview.PNG](attachment:Paraview.PNG)
